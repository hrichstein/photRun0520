# %%
# from photutils import aperture_photometry

# positions = np.transpose((sources['xcentroid'], sources['ycentroid']))
# apertures_r3 = CircularAperture(positions, r=3.)


# from photutils import CircularAnnulus

# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy.io import fits
from photutils import aperture_photometry,CircularAnnulus

# %%
from photutils import CircularAperture

# %%
from astropy.stats import sigma_clipped_stats

# %%
image = 'hor1DRCs/jdan20010_drc.fits'

fits.info(image)

hdu = fits.open(image)
sci = hdu[1].data
hdr = hdu[0].header
tab = hdu[4].data

hdu.close()
# Out:
# Filename: hor1DRCs/jdan20010_drc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     885   ()
#   1  SCI           1 ImageHDU        86   (4216, 4247)   float32
#   2  WHT           1 ImageHDU        47   (4216, 4247)   float32
#   3  CTX           1 ImageHDU        40   (4216, 4247)   int32
#   4  HDRTAB        1 BinTableHDU    633   10R x 312C   [9A, 3A, K, D, D, D, D, D, D, D, D, D, D, D, D, D, K, 3A, 9A, 7A, 18A, 4A, D, D, D, D, 3A, D, D, D, D, D, D, D, D, D, D, D, D, K, 8A, 23A, D, D, D, D, K, K, K, 8A, K, 23A, 9A, 21A, K, 4A, K, D, K, K, K, K, 23A, D, D, D, D, K, K, 3A, 3A, 4A, 4A, L, D, D, D, 3A, 1A, K, D, D, D, 13A, 3A, 4A, 4A, 12A, 12A, 23A, 8A, 23A, 10A, 10A, D, D, 3A, 3A, 23A, 4A, 8A, 7A, 23A, D, K, D, 6A, 9A, 8A, D, D, L, 4A, 18A, 3A, K, 5A, 7A, 3A, D, 13A, 8A, 4A, 3A, L, K, L, K, L, K, K, D, D, D, D, D, D, 3A, 1A, D, 23A, D, D, D, 3A, 23A, L, 1A, 3A, 6A, D, 3A, 6A, K, D, D, D, D, D, D, D, D, D, D, 23A, D, D, D, D, 3A, D, D, D, 1A, K, K, K, K, K, K, 23A, K, 5A, 7A, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, 12A, D, 24A, 23A, D, 1A, 1A, D, K, D, D, 1A, 1A, D, 4A, K, D, K, 8A, D, D, D, D, D, 23A, 23A, D, 8A, D, 29A, D, 3A, D, L, D, D, 3A, 5A, 12A, 1A, D, 3A, K, 1A, 1A, 1A, 1A, D, D, D, D, D, D, 4A, D, 4A, D, 4A, K, 4A, 3A, 1A, L, K, K, 1A, D, D, D, D, K, 3A, L, L, 6A, L, D, D, 12A, D, D, 3A, 8A, 1A, D, K, D, L, 29A, L, 5A, 4A, K, D, D, D, D, D, D, D, D, D, D, D, D, D, D, 12A, 12A, 3A, 3A]

# %%
temp_sci = sci*hdr['texptime'] + (0.03/0.05)**2*np.sum(tab['mdrizsky'])/2

# %%
pos_file = np.genfromtxt('sDRC_2606/matchedDRCaper2906_bkgd.dat',names=True)

# %%
xpos = pos_file['xr_f606w']-0.5
ypos = pos_file['yr_f606w']-0.5

# %%
loc = np.array([xpos,ypos])
print(loc.shape)

positions = np.transpose(loc)
print(positions.shape)
print(positions[:10,:])
# Out:
# (2, 1368)
# (1368, 2)
# [[4076.4058  576.1948]
#  [4109.1333 1023.4497]
#  [4109.0664 2540.4456]
#  [4143.6416 2033.4398]
#  [4071.4421 1742.3646]
#  [3998.9187  667.9089]
#  [4002.3486 1445.111 ]
#  [3984.6777  194.568 ]
#  [4065.0552 1337.8058]
#  [4011.4626  259.3171]]

# %%
apertures = CircularAperture(positions, r=5.)

fig,ax = plt.subplots(figsize=(10,10))

ax.imshow(sci, cmap='Greys', origin='lower')
apertures.plot(color='blue', lw=1.5, alpha=0.5)



plt.show()

# %%
apertures_r4 = CircularAperture(positions, r=4.)

rawflux_r4 = aperture_photometry(temp_sci, apertures_r4)
print(rawflux_r4)
# Out:
#  id   xcenter   ycenter     aperture_sum
#         pix       pix
# ---- --------- --------- ------------------
#    1 4076.4058  576.1948  6953.070113856595
#    2 4109.1333 1023.4497 10184.498645541324
#    3 4109.0664 2540.4456 10531.845182432997
#    4 4143.6416 2033.4398   48665.6532763354
#    5 4071.4421 1742.3646  31564.13250783851
#    6 3998.9187  667.9089  7364.973176135653
#    7 4002.3486  1445.111 6813.4822799646545
#    8 3984.6777   194.568 10213.525019173285
#    9 4065.0552 1337.8058  6767.600159397084
#   10 4011.4626  259.3171  13093.16144358292
#  ...       ...       ...                ...
# 1359  174.0259 1840.0088   9179.31076473029
# 1360  161.6744 1737.4998  23365.85771030307
# 1361  156.8175  1703.041  8017.904154396545
# 1362  238.8237 2994.5317 16152.329257549332
# 1363  260.1625 3278.1619  10887.12336836542
# 1364  264.2503 3869.4104  7491.402236222572
# 1365  278.8444 3621.6318   6895.11746275246
# 1366  188.6674 3497.2051  18458.84110983001
# 1367  192.3142 3532.7405 11750.314092173561
# 1368  201.2262 3673.6182  38098.45192204864
# Length = 1368 rows

# %%
annulus_apertures = CircularAnnulus(positions, r_in=9., r_out=12.)

# %%
data = temp_sci.copy()

# %%
annulus_masks = annulus_apertures.to_mask(method='center')

bkg_median = []
for mask in annulus_masks:
    
    annulus_data = mask.multiply(data)
    annulus_data_1d = annulus_data[mask.data > 0]
    _, median_sigclip, _ = sigma_clipped_stats(annulus_data_1d)
    bkg_median.append(median_sigclip)

bkg_median = np.array(bkg_median)
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]

# %%
rawflux_r4['annulus_median'] = bkg_median
print(rawflux_r4['annulus_median'])
# Out:
#   annulus_median
# ------------------
# 108.01699829101562
# 107.18997192382812
#   101.963623046875
# 112.19859313964844
# 104.70746612548828
# 106.61402130126953
# 105.77669525146484
# 113.19987869262695
# 108.77640533447266
# 112.89155578613281
#                ...
# 105.73811721801758
# 107.89606094360352
# 109.34430313110352
# 107.22586059570312
# 105.10013580322266
# 109.50621032714844
# 115.75445556640625
# 106.79839706420898
# 116.36150360107422
#  106.6308822631836
# 116.78489303588867
# Length = 1368 rows

# %%
rawflux_r4['aper_bkg'] = bkg_median*apertures_r4.area
print(rawflux_r4['aper_bkg'])
# Out:
#      aper_bkg
# ------------------
#  5429.526532702015
#  5387.955653350314
#  5125.250705559382
#  5639.716415210075
#  5263.171301693377
#  5359.005217435745
#  5316.916619568133
#  5690.046516608201
#  5467.698494122958
# 5674.5485169605945
#                ...
#  5314.977476104647
#  5423.447558587222
#  5496.244150857124
#  5389.759614756867
#  5282.909032491102
#  5504.382494179652
#  5818.453555643328
#  5368.272954113355
#  5848.967117980752
#  5359.852741821052
#  5870.248992189082
# Length = 1368 rows

# %%
rawflux_r4['final_phot'] = rawflux_r4['aperture_sum'] - rawflux_r4['aper_bkg']
print(rawflux_r4['final_phot'])
# Out:
#     final_phot
# ------------------
# 1523.5435811545794
#   4796.54299219101
#  5406.594476873614
#  43025.93686112532
# 26300.961206145133
# 2005.9679586999082
# 1496.5656603965217
# 4523.4785025650835
# 1299.9016652741257
#  7418.612926622325
#                ...
#  4566.288119860644
#  3755.863206143067
# 17869.613559445945
# 2628.1445396396775
# 10869.420225058231
#  5382.740874185769
#  1672.948680579244
# 1526.8445086391048
# 12609.873991849257
#  6390.461350352509
#  32228.20292985956
# Length = 1368 rows

# %%
EEVband = 0.839 #4 pix rad
EEIband  = 0.830 #4 pix rad

ZPV = 26.667
ZPI = 26.779

# %%
mask_negative = (rawflux_r4['final_phot'] > 0) 
rawflux_pos_r4 = rawflux_r4[mask_negative]

# %%
final_phot = -2.5*np.log10(rawflux_pos_r4['final_phot']/EEVband) + ZPV
print(final_phot)
# Out:
#     final_phot
# ------------------
# 18.519267697610957
# 17.274084048383862
#  17.14409541102558
#  14.89207906313247
# 15.426475850343875
# 18.220594922672515
#  18.53866546244174
# 17.337723575293804
#  18.69162865177409
#  16.80059812223882
#                ...
# 17.327496625142253
# 17.539630486416634
# 15.846117000216552
# 17.927281786152104
# 16.385888953487374
# 17.148896218750238
# 18.417698355229266
#  18.51691787340979
#  16.22462803514697
#  16.96257437065082
# 15.205814678114423
# Length = 1368 rows

# %%
plt.hist(final_phot)
plt.show()

# %%
flux = 10**((pos_file['magr_f606w'] - ZPV)/(-2.5) ) *EEVband
print(flux[:10])
# Out:
# [0.34251687 1.04424393 1.14246252 9.32657014 5.69799365 0.43355277
#  0.32988454 0.99899189 0.33244665 1.62810332]

# %%
image = 'hor1DRCs/jdan21010_drc.fits'

hdu = fits.open(image)
sci = hdu[1].data
hdr2 = hdu[0].header
tab = hdu[4].data

hdu.close()

# %%
temp_sci = sci*hdr2['texptime'] + (0.03/0.05)**2*np.sum(tab['mdrizsky'])/2

xpos = pos_file['xr_f814w']-0.5
ypos = pos_file['yr_f814w']-0.5

loc = np.array([xpos,ypos])

positions = np.transpose(loc)

apertures_r4 = CircularAperture(positions, r=4.)

rawflux_r4_814 = aperture_photometry(temp_sci, apertures_r4)
annulus_apertures = CircularAnnulus(positions, r_in=9., r_out=12.)

data = temp_sci.copy()

annulus_masks = annulus_apertures.to_mask(method='center')

bkg_median = []
for mask in annulus_masks:
    
    annulus_data = mask.multiply(data)
    annulus_data_1d = annulus_data[mask.data > 0]
    _, median_sigclip, _ = sigma_clipped_stats(annulus_data_1d)
    bkg_median.append(median_sigclip)

bkg_median = np.array(bkg_median)
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]

# %%
rawflux_r4_814['annulus_median'] = bkg_median
rawflux_r4_814['aper_bkg'] = bkg_median*apertures_r4.area
rawflux_r4_814['final_phot'] = rawflux_r4_814['aperture_sum'] - rawflux_r4_814['aper_bkg']

mask_negative = (rawflux_r4_814['final_phot'] > 0) 
rawflux_pos_r4_814 = rawflux_r4_814[mask_negative]

final_phot_814 = -2.5*np.log10(rawflux_pos_r4_814['final_phot']/EEVband) + ZPV
print(final_phot_814)
# Out:
#     final_phot
# ------------------
# 18.590470163881463
# 17.320344783707476
#  17.40899732477817
#  15.38750723993363
# 15.827129904136273
# 18.124054714620577
# 18.594236080091093
# 17.890066352126645
# 18.524168560694157
# 16.947810886848536
#                ...
# 17.485333672209034
# 17.686531103896158
#  16.29720587390009
#  18.80344526899605
# 16.746626776195292
# 17.342129643904386
# 17.802745923955502
# 18.623889040965167
# 16.621535789580744
# 17.193338069706787
# 15.702416393586184
# Length = 1368 rows

# %%
fig, ax = plt.subplots()

# ax.scatter(final_phot,rawflux_r4['aper_bkg']/hdr['texptime'])
# ax.scatter(final_phot_814,rawflux_r4_814['aper_bkg']/hdr2['texptime'])

ax.scatter(final_phot,rawflux_r4['aper_bkg'])
ax.scatter(final_phot_814,rawflux_r4_814['aper_bkg'])

ax.set_ylabel('BKG counts')
ax.set_xlabel('Magnitude')

ax.set_ylim(0,110000)
ax.set_xlim(8,20)

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(final_phot,rawflux_r4['aper_bkg']/hdr['texptime'])
ax.scatter(final_phot_814,rawflux_r4_814['aper_bkg']/hdr2['texptime'])

# ax.scatter(final_phot,rawflux_r4['aper_bkg'])
# ax.scatter(final_phot_814,rawflux_r4_814['aper_bkg'])

ax.set_ylabel('BKG counts')
ax.set_xlabel('Magnitude')

ax.set_ylim(0,40)
ax.set_xlim(8,20)

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(pos_file['m606cAPER'],pos_file['sky606APER'])
ax.scatter(pos_file['m814cAPER'],pos_file['sky814APER'])

ax.set_ylabel('BKG counts')
ax.set_xlabel('Magnitude')

# ax.set_ylim(0,40)
# ax.set_xlim(8,20)

plt.show()

# %%
tab['mdrizsky']
# Out:
# array([52.74571609, 52.74571609, 67.36671448, 67.36671448,  4.54804945,
#         4.54804945, 51.5254631 , 51.5254631 , 55.70343399, 55.70343399])

# %%
fig,ax = plt.subplots()

ax.imshow(sci,origin='lower',interpolation='nearest')
plt.tight_layout()
plt.show()
